# %%
import pandas as pd

dataset = pd.read_csv('C:/Users/fiori/OneDrive/Documenti/Magistrale/Tesi/FedericoFiorio_Tesi/improved_aesthetics_5plus.csv')

# %%
dataset
# Out:
#                                                       URL  \
# 0       https://cdn.onekindesign.com/wp-content/upload...
# 1       https://cdn1.bigcommerce.com/server3400/9la52e...
# 2       https://img4640.weyesimg.com/uploads/fsszled-h...
# 3       https://cdn.shopify.com/s/files/1/2659/1590/pr...
# 4       https://trishcoonrod.com/wp-content/uploads/20...
# ...                                                   ...
# 647430  https://www.motorcyclespecs.co.za/Gallery_A-L_...
# 647431  https://slotopaint.com/wp-content/uploads/2019...
# 647432  https://www.contemporist.com/wp-content/upload...
# 647433  https://mapi.associatedpress.com/v1/items/c740...
# 647434  http://assets.cat5.com/images/catalog/products...
#
#                                                      TEXT   WIDTH  HEIGHT  \
# 0       Small Home Office Design Ideas: 28 Dreamy Home...  1188.0  1392.0
# 1                Martine Dining Chair - Brown Leatherette   193.0   290.0
# ...

# %%
#keep first 30k
import numpy as np
URLs = np.array(dataset.iloc[:, 0])
URLs
# Out:
# array(['https://cdn.onekindesign.com/wp-content/uploads/2016/07/Home-Office-Library-Ideas-11-1-Kindesign.jpg',
#        'https://cdn1.bigcommerce.com/server3400/9la52efk/products/204/images/700/SDR2619Bb__53584.1488168516.220.290.jpg?c=2',
#        'https://img4640.weyesimg.com/uploads/fsszled-housing.com/images/15663791281841.jpg?imageView2/2/w/800/h/800/q/75',
#        ...,
#        'https://www.contemporist.com/wp-content/uploads/2018/02/modern-stairs-railing-190218-1149-08-800x1202.jpg',
#        'https://mapi.associatedpress.com/v1/items/c74039faacca4db0bae1c6196bce06a2/preview/preview.jpg?s=690x',
#        'http://assets.cat5.com/images/catalog/products/3/3/5/1/4/0-325-justin-original-work-boots-11-stampede-square-toe-waxy-brown-hunter-green.jpg?v=9053'],
#       dtype=object)

# %%
URLs[30537]
# Out:
# 'https://media.gettyimages.com/photos/andreas-seppi-of-italy-throws-his-racket-to-the-ball-after-missing-a-picture-id483065289?k=6&amp;m=483065289&amp;s=612x612&amp;w=0&amp;h=hJnTFaC5FKqadiloM8qgMccAQ_VE6C4kCUR_djliEN0='

# %%
import urllib.request

# %%
import socket

last_image =997

socket.setdefaulttimeout(15)

for i in range(last_image, 4000):
    try:
        print(i)
        urllib.request.urlretrieve(URLs[i], "C:/Users/fiori/OneDrive/Documenti/Magistrale/Tesi/FedericoFiorio_Tesi/code/LAION-5v+/" +str(i) +".jpg")
    except:
        print(i)
        pass
# Out:
# 997
# 998
# 998
# 999
# 999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1008
# 1009
# 1009
# 1010
# 1010
# 1011
# 1012
# 1012
# 1013
# 1013
# 1014
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1023
# 1024
# 1025
# 1026
# 1027
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1041
# 1042
# 1043
# 1044
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1050
# 1051
# 1052
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1085
# 1086
# 1087
# 1088
# 1089
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1112
# 1113
# 1113
# 1114
# 1115
# ...
